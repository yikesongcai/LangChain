# %% [markdown]
# # 1、模型调用的分类
#
# 角度1：按照模型功能的不同
#
# 非对话模型：（LLMs、Text Model）
#
# 对话模型：（Chat Models）（推荐）
#
# 嵌入模型：（embedding model）
#
# 角度2：按照模型调用时，参数书写位置的不同（api-key、base-url、model-name）
#
# 硬编码的方式：将参数书写在代码中
#
# 使用环境变量的方式
#
# 使用配置文件的方式（推荐）
#
# 角度3：具体API的调用
#
# 使用Langchain提供的API (推荐)
#
# 使用openAI的官方API
#
# 使用其他平台提供的API
#
# ## 角度1：非对话模型的调用

# %%
import os
from langchain_openai import ChatOpenAI
import dotenv
from langchain_openai import OpenAI
from openai.types import ChatModel

# from langchain_deepseek import DeepSeek
dotenv.load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("DEEPSEEK_API_KEY")
os.environ["OPENAI_BASE_URL"] = os.getenv("DEEPSEEK_API_URL")
###########核心代码############
llm = OpenAI()
str = llm.invoke("写一首关于春天的诗")
# 直接输入字符串
print(str)
print(type(str))
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[7], line 13
#      11 ###########核心代码############
#      12 llm = OpenAI()
# ---> 13 str = llm.invoke("写一首关于春天的诗")
#      14 # 直接输入字符串
#      15 print(str)
#
# File E:\software\Miniconda3\envs\langchain\lib\site-packages\langchain_core\language_models\llms.py:375, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     364 @override
#     365 def invoke(
#     366     self,
#    (...)
#     371     **kwargs: Any,
#     372 ) -> str:
#     373     config = ensure_config(config)
#     374     return (
# --> 375         self.generate_prompt(
#     376             [self._convert_input(input)],
#     377             stop=stop,
#     378             callbacks=config.get("callbacks"),
#     379             tags=config.get("tags"),
#     380             metadata=config.get("metadata"),
# ...

# %% [markdown]
# # 角度1：对话模型

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage
import os
import dotenv
dotenv.load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("DEEPSEEK_API_KEY")
os.environ["OPENAI_BASE_URL"] = os.getenv("DEEPSEEK_API_URL")
########核心代码############
chat_model = ChatOpenAI(model="deepseek-chat")
messages = [
    SystemMessage(content="我是人工智能助手，我叫小智"),
    HumanMessage(content="你好，我是小明，很高兴认识你")
]

#输入：list[message]
#输出

response = chat_model.invoke(messages) # 输入消息列表
print(type(response)) # <class 'langchain_core.messages.ai.AIMessage'>
print(response.content)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# 你好小明！很高兴认识你！我是小智，随时准备为你提供帮助或聊天。有什么想聊的话题或者需要帮忙的地方吗？ 😊

# %% [markdown]
# # 角度2：参数位置不同举例
# ## 硬编码方式

# %%
from langchain_openai import ChatOpenAI
# 调用非对话模型：
# llms = OpenAI(...)

# 调用对话模型：
chat_model = ChatOpenAI(
    #必须要设置的3个参数
    model_name="deepseek-chat",
    base_url="https://api.deepseek.com/v1",
    api_key="sk-0babac29da05424eb0cc644a5994e41a",

)

#调用模型
response = chat_model.invoke("什么试langchain")

#查看响应的文本
print(response.content)
# Out:
# 我来为你详细介绍一下 LangChain。
#
# ## 什么是 LangChain？
#
# **LangChain** 是一个用于开发由大型语言模型（LLM）驱动的应用程序的框架。它不是一个独立的 AI 模型，而是一个工具集，帮助开发者更高效地构建基于 LLM 的应用。
#
# ## 核心概念
#
# ### 1. **链（Chains）**
# - 将多个组件连接起来，完成复杂任务
# - 例如：用户问题 → 检索相关信息 → 生成回答
#
# ### 2. **代理（Agents）**
# - 让 LLM 决定使用哪些工具来完成任务
# - 可以调用搜索引擎、计算器、数据库等
#
# ### 3. **记忆（Memory）**
# - 让对话有上下文记忆
# - 记住之前的对话历史
#
# ### 4. **文档加载器（Document Loaders）**
# - 从各种来源加载数据（PDF、网页、数据库等）
#
# ## 主要功能
#
# ### 🔧 **与各种 LLM 集成**
# - 支持 OpenAI GPT、Claude、本地模型等
# - 统一接口，方便切换模型
#
# ### 📚 **检索增强生成（RAG）**
# - 从外部知识库检索信息
# - 结合检索结果生成更准确的回答
#
# ### 🛠️ **工具调用**
# - 让 LLM 使用外部工具
# - 例如：查询天气、执行计算、搜索网络
#
# ### 🔌 **丰富的生态系统**
# - 大量预构建组件
# - 社区贡献的模板和工具
#
# ## 简单示例
#
# ```python
# from langchain.llms import OpenAI
# from langchain.chains import LLMChain
# from langchain.prompts import PromptTemplate
#
# # 创建提示模板
# prompt = PromptTemplate(
#     input_variables=["product"],
#     template="为{product}写一个广告标语"
# )
#
# # 创建链
# llm = OpenAI()
# ...

# %% [markdown]
# 演示非对话模型

# %%
from langchain_openai import OpenAI
# 调用非对话模型：
llm = OpenAI(
    #必须要设置的3个参数
    # model_name="deepseek-chat",   注释掉使用默认模型
    base_url="https://api.deepseek.com/v1",
    api_key="sk-0babac29da05424eb0cc644a5994e41a",

)

#调用模型
response = llm.invoke("什么试langchain")

#查看响应的文本
print(response)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[12], line 12
#       3 llm = OpenAI(
#       4     #必须要设置的3个参数
#       5     # model_name="deepseek-chat",   注释掉使用默认模型
#    (...)
#       8
#       9 )
#      11 #调用模型
# ---> 12 response = llm.invoke("什么试langchain")
#      14 #查看响应的文本
#      15 print(response)
#
# File E:\software\Miniconda3\envs\langchain\lib\site-packages\langchain_core\language_models\llms.py:375, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     364 @override
#     365 def invoke(
#     366     self,
#    (...)
#     371     **kwargs: Any,
#     372 ) -> str:
#     373     config = ensure_config(config)
#     374     return (
# --> 375         self.generate_prompt(
#     376             [self._convert_input(input)],
#     377             stop=stop,
#     378             callbacks=config.get("callbacks"),
# ...

# %% [markdown]
# ## 使用环境变量的方式
