# %%
import os
from http.client import responses

import dotenv
from langchain_core.messages import AIMessage, HumanMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

dotenv.load_dotenv()

os.environ['OPENAI_API_KEY'] = os.getenv("DEEPSEEK_API_KEY")
os.environ['OPENAI_BASE_URL'] = os.getenv("DEEPSEEK_BASE_URL")

llm = ChatOpenAI(model="deepseek-chat")

# %%
def chat_with_model(answer):


    # 2、提供提示词模板： ChatPromptTemplate
    prompt_template = ChatPromptTemplate.from_messages([
        ("system","你是一个人工智能助手，你的名字叫小智"),
        ("human","{question}")
    ])


    while True:
        # 3、获取chain，并调用大模型得到响应
        chain = prompt_template | llm
        response = chain.invoke({"question":answer})


        # 4、输出大模型的响应
        print(f"模型回复：{response.content}")

        # 5、继续获取用户的问题
        user_input = input("你还有其他问题吗？(输入'退出'时，结束会话)")

        # 6、指明退出循环的方式
        if(user_input == "退出"):
            break

        # 7、将上述新生成的消息存放到提示词模板的消息列表中
        prompt_template.messages.append(AIMessage(content=response.content))
        prompt_template.messages.append(HumanMessage(content=user_input))


chat_with_model("你好，很高兴认识你")
# Out:
# 模型回复：你好！我也很高兴认识你！😊 我是小智，一个AI助手，随时准备为你提供帮助。无论是回答问题、聊天，还是协助解决问题，我都很乐意为你服务！有什么我可以帮你的吗？
# 模型回复：哈哈，这个问题很有趣！😄 从字面意思来看，“李白”的名字确实有“白”字，但这里的“白”并不是指肤色哦。
#
# **李白的名字由来**：
# - 一种说法是，他出生时母亲梦见“长庚星”（即太白金星），因此取名“白”，字“太白”，寓意星辰之光。
# - 另一种说法是，“白”在古代有“明亮”“坦荡”的象征，与其豪放洒脱的性格相合。
#
# **历史上的李白**：
# - 作为诗人，他一生游历四方，饮酒赋诗，皮肤可能更接近风霜之色（毕竟唐朝没有防晒霜嘛～）。
# - 不过，他的诗歌倒是“很白”——语言清新自然，飘逸如云，被赞为“清水出芙蓉，天然去雕饰”！
#
# 所以，李白或许不“白”，但他的诗一定“白”得耀眼！✨ 需要聊聊他的诗吗？
# 模型回复：李白的传世名作很多，但若论**流传最广、影响力最大**的一首，当属 **《静夜思》**：
#
# **床前明月光，疑是地上霜。
# 举头望明月，低头思故乡。**
#
# ### 为何是这首诗？
# 1. **语言极简，意境深远**：20个字，用最朴实的画面（月光、霜、举头、低头）勾起了人类共通的思乡之情，跨越千年依然直击人心。
# 2. **文化烙印深刻**：它是中国人启蒙教育的必读诗，几乎人人能诵，甚至成了一种文化符号。
# 3. **国际知名度高**：在东亚文化圈乃至西方汉学研究中，它常被视为中国古典诗歌的“入门代表作”。
#
# ### 其他“著名竞争者”：
# - **《将进酒》**：“君不见黄河之水天上来…”——豪情万丈，展现李白狂放不羁的巅峰之作。
# - **《望庐山瀑布》**：“飞流直下三千尺…”——浪漫想象的极致，小学生必背“网红诗”。
# - **《蜀道难》**：“噫吁嚱，危乎高哉！”——以奇险笔墨写尽山川壮丽，被称为“奇之又奇”的典范。
#
# ### 有趣的是…
# 李白自己可能没想到，《静夜思》会成为他的“第一标签”。毕竟他更以“酒中仙”“仗剑天涯”的豪侠形象自许，但这首宁静的小诗，反而因**人类情感的永恒共鸣**，成了他穿越时间的最强声音。
#
# 如果需要，我可以为你逐句解读他的任何诗作！ 🌙
# 模型回复：你刚才提到的诗人是 **李白**（字太白，号青莲居士），唐代最著名的浪漫主义诗人，被后世尊称为“**诗仙**”。
#
# 你们之前的对话围绕他展开，讨论了：
# 1. 他的名字是否“白”（名字由来与寓意）；
# 2. 他最著名的诗《静夜思》及其他代表作。
#
# 需要继续聊聊李白的生平、诗歌风格，或其他相关话题吗？ 😊
